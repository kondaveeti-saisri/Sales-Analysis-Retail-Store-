# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
df = pd.read_csv(r"V:\sai\dsprojects\retailsales\Warehouse_and_Retail_Sales.csv")

# %%
df
# Out:
#         YEAR  MONTH                             SUPPLIER ITEM CODE  \
# 0       2020      1    REPUBLIC NATIONAL DISTRIBUTING CO    100009
# 1       2020      1                            PWSWN INC    100024
# 2       2020      1              RELIABLE CHURCHILL LLLP      1001
# 3       2020      1            LANTERNA DISTRIBUTORS INC    100145
# 4       2020      1                 DIONYSOS IMPORTS INC    100293
# ...      ...    ...                                  ...       ...
# 307640  2020      9              BOSTON BEER CORPORATION     98868
# 307641  2020      9  GLOBAL OCEAN AND AIR CARGO SERVICES     98884
# 307642  2020      9                         HEINEKEN USA     98906
# 307643  2020      9              RELIABLE CHURCHILL LLLP     98914
# 307644  2020      9                CONSTANTINE WINES INC     98930
#
#                            ITEM DESCRIPTION ITEM TYPE  RETAIL SALES  \
# 0                       BOOTLEG RED - 750ML      WINE          0.00
# ...

# %%
print(df.head())
# Out:
#    YEAR  MONTH                           SUPPLIER ITEM CODE  \
# 0  2020      1  REPUBLIC NATIONAL DISTRIBUTING CO    100009
# 1  2020      1                          PWSWN INC    100024
# 2  2020      1            RELIABLE CHURCHILL LLLP      1001
# 3  2020      1          LANTERNA DISTRIBUTORS INC    100145
# 4  2020      1               DIONYSOS IMPORTS INC    100293
#
#                       ITEM DESCRIPTION ITEM TYPE  RETAIL SALES  \
# 0                  BOOTLEG RED - 750ML      WINE          0.00
# 1            MOMENT DE PLAISIR - 750ML      WINE          0.00
# 2  S SMITH ORGANIC PEAR CIDER - 18.7OZ      BEER          0.00
# 3        SCHLINK HAUS KABINETT - 750ML      WINE          0.00
# 4       SANTORINI GAVALA WHITE - 750ML      WINE          0.82
#
#    RETAIL TRANSFERS  WAREHOUSE SALES
# 0               0.0              2.0
# 1               1.0              4.0
# 2               0.0              1.0
# 3               0.0              1.0
# ...

# %%
print(df.isnull().sum())
# Out:
# YEAR                  0
# MONTH                 0
# SUPPLIER            167
# ITEM CODE             0
# ITEM DESCRIPTION      0
# ITEM TYPE             1
# RETAIL SALES          3
# RETAIL TRANSFERS      0
# WAREHOUSE SALES       0
# dtype: int64

# %%
df['SUPPLIER'] = df['SUPPLIER'].fillna("Unknown")
df['ITEM TYPE'] = df['ITEM TYPE'].fillna(df['ITEM TYPE'].mode()[0])
df['RETAIL SALES'] = df['RETAIL SALES'].fillna(0)

# %%
df
# Out:
#         YEAR  MONTH                             SUPPLIER ITEM CODE  \
# 0       2020      1    REPUBLIC NATIONAL DISTRIBUTING CO    100009
# 1       2020      1                            PWSWN INC    100024
# 2       2020      1              RELIABLE CHURCHILL LLLP      1001
# 3       2020      1            LANTERNA DISTRIBUTORS INC    100145
# 4       2020      1                 DIONYSOS IMPORTS INC    100293
# ...      ...    ...                                  ...       ...
# 307640  2020      9              BOSTON BEER CORPORATION     98868
# 307641  2020      9  GLOBAL OCEAN AND AIR CARGO SERVICES     98884
# 307642  2020      9                         HEINEKEN USA     98906
# 307643  2020      9              RELIABLE CHURCHILL LLLP     98914
# 307644  2020      9                CONSTANTINE WINES INC     98930
#
#                            ITEM DESCRIPTION ITEM TYPE  RETAIL SALES  \
# 0                       BOOTLEG RED - 750ML      WINE          0.00
# ...

# %%
print(df.isnull().sum())
# Out:
# YEAR                0
# MONTH               0
# SUPPLIER            0
# ITEM CODE           0
# ITEM DESCRIPTION    0
# ITEM TYPE           0
# RETAIL SALES        0
# RETAIL TRANSFERS    0
# WAREHOUSE SALES     0
# dtype: int64

# %%
monthly_sales = df.groupby('MONTH')['RETAIL SALES'].sum()
print(monthly_sales)
# Out:
# MONTH
# 1     226211.07
# 2     157917.67
# 3     193852.33
# 4      80342.58
# 5      94953.10
# 6     188217.65
# 7     277927.73
# 8     177740.39
# 9     254687.49
# 10    177467.37
# 11    199947.50
# 12    131634.49
# Name: RETAIL SALES, dtype: float64

# %%
import matplotlib.pyplot as plt

# Plot monthly sales
plt.figure(figsize=(10, 5))
plt.plot(monthly_sales.index, monthly_sales.values, marker='o', linestyle='-', color='b')

# Add labels and title
plt.xlabel("Month")
plt.ylabel("Retail Sales")
plt.title("Monthly Retail Sales Trend")
plt.xticks(range(1, 13))  # Ensure x-axis shows all months from 1 to 12
plt.grid(True)

# Show the plot
plt.show()

# %%
import seaborn as sns

# Group sales by ITEM TYPE
category_sales = df.groupby('ITEM TYPE')['RETAIL SALES'].sum().sort_values(ascending=False)

# Create a bar chart
plt.figure(figsize=(10, 5))
sns.barplot(x=category_sales.index, y=category_sales.values, palette="viridis")

# Add labels and title
plt.xlabel("Item Type")
plt.ylabel("Retail Sales")
plt.title("Total Sales by Item Type")
plt.xticks(rotation=45)  # Rotate for better readability

# Show the plot
plt.show()
# Out:
# C:\Users\manoh\AppData\Local\Temp\ipykernel_9028\1378482196.py:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=category_sales.index, y=category_sales.values, palette="viridis")

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Group sales by ITEM TYPE
category_sales = df.groupby('ITEM TYPE')['RETAIL SALES'].sum().sort_values(ascending=False)

# Create a bar chart
plt.figure(figsize=(10, 5))
sns.barplot(x=category_sales.index, y=category_sales.values, hue=category_sales.index, palette="viridis", legend=False)

# Add labels and title
plt.xlabel("Item Type")
plt.ylabel("Retail Sales")
plt.title("Total Sales by Item Type")
plt.xticks(rotation=45)  # Rotate for better readability

# Show the plot
plt.show()

# %%
# Group sales by SUPPLIER and sort by highest sales
supplier_sales = df.groupby('SUPPLIER')['RETAIL SALES'].sum().sort_values(ascending=False).head(10)

# Create a bar chart
plt.figure(figsize=(12, 6))
sns.barplot(x=supplier_sales.values, y=supplier_sales.index, palette="coolwarm")

# Add labels and title
plt.xlabel("Retail Sales")
plt.ylabel("Supplier")
plt.title("Top 10 Suppliers by Retail Sales")

# Show the plot
plt.show()
# Out:
# C:\Users\manoh\AppData\Local\Temp\ipykernel_9028\2180486320.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=supplier_sales.values, y=supplier_sales.index, palette="coolwarm")

# %%
# Group sales by SUPPLIER and sort by highest sales
supplier_sales = df.groupby('SUPPLIER')['RETAIL SALES'].sum().sort_values(ascending=False).head(10)

# Create a bar chart
plt.figure(figsize=(12, 6))
sns.barplot(x=supplier_sales.values, y=supplier_sales.index, hue=supplier_sales.index, palette="coolwarm", legend=False)

# Add labels and title
plt.xlabel("Retail Sales")
plt.ylabel("Supplier")
plt.title("Top 10 Suppliers by Retail Sales")

# Show the plot
plt.show()
